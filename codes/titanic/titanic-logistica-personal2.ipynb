# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
def custom_sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# def custom_logistic_regression(X, y, alpha, num_iterations):
#     m, n = X.shape
#     weights = np.zeros((n, 1))
#     for i in range(num_iterations):
#         z = np.dot(X, weights)
#         h = custom_sigmoid(z)
#         gradient = np.dot(X.T, (h - y)) / m
#         weights -= alpha * gradient
#     return weights

# %%
# Cargar datos
df = pd.read_csv("./data/Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 706          886         0       3
# 707          887         0       2
# 708          888         1       1
# 709          890         1       1
# 710          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 706               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 707                              Montvila, Rev. Juozas    male  27.0      0
# 708                       Graham, Miss. Margaret Edith  female  19.0      0
# 709                              Behr, Mr. Karl Howell    male  26.0      0
# 710                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 706      5            382652  29.1250   NaN        Q
# 707      0            211536  13.0000   NaN        S
# 708      0            112053  30.0000   B42        S
# 709      0            111369  30.0000  C148        C
# 710      0            370376   7.7500   NaN        Q
#
# [711 rows x 12 columns]

# %%
# Realiza una limpieza básica de datos
df = df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)  # Elimina columnas no importantes
df = df.dropna()  # Elimina filas con valores perdidos

# %%
# Crea variables dummy para las columnas categóricas
df = pd.get_dummies(df, columns=['Sex', 'Embarked'])

# %%
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500           0         1
# 1           1       1  38.0      1      0  71.2833           1         0
# 2           1       3  26.0      0      0   7.9250           1         0
# 3           1       1  35.0      1      0  53.1000           1         0
# 4           0       3  35.0      0      0   8.0500           0         1
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 706         0       3  39.0      0      5  29.1250           1         0
# 707         0       2  27.0      0      0  13.0000           0         1
# 708         1       1  19.0      0      0  30.0000           1         0
# 709         1       1  26.0      0      0  30.0000           0         1
# 710         0       3  32.0      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 706           0           1           0
# 707           0           0           1
# 708           0           0           1
# 709           1           0           0
# 710           0           1           0
#
# [711 rows x 11 columns]

# %%
X = df.drop('Survived', axis=1)

# %%
X
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0         3  22.0      1      0   7.2500           0         1           0
# 1         1  38.0      1      0  71.2833           1         0           1
# 2         3  26.0      0      0   7.9250           1         0           0
# 3         1  35.0      1      0  53.1000           1         0           0
# 4         3  35.0      0      0   8.0500           0         1           0
# ..      ...   ...    ...    ...      ...         ...       ...         ...
# 706       3  39.0      0      5  29.1250           1         0           0
# 707       2  27.0      0      0  13.0000           0         1           0
# 708       1  19.0      0      0  30.0000           1         0           0
# 709       1  26.0      0      0  30.0000           0         1           1
# 710       3  32.0      0      0   7.7500           0         1           0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 706           1           0
# 707           0           1
# 708           0           1
# 709           0           0
# 710           1           0
#
# [711 rows x 10 columns]

# %%
y = df['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 706    0
# 707    0
# 708    1
# 709    1
# 710    0
# Name: Survived, Length: 711, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_female  Sex_male  Embarked_C  \
# 691       3   4.0      1      1   11.1333           0         1           0
# 266       1  38.0      0      1  153.4625           0         1           0
# 17        2  35.0      0      0   26.0000           0         1           0
# 477       1  27.0      0      0   30.5000           0         1           0
# 302       3  19.0      0      0    7.7750           0         1           0
# ..      ...   ...    ...    ...       ...         ...       ...         ...
# 359       3   5.0      2      1   19.2583           1         0           1
# 192       2  33.0      0      0   12.2750           0         1           0
# 629       3  25.0      0      0    7.8958           0         1           0
# 559       2  45.0      0      0   13.5000           1         0           0
# 684       3  41.0      2      0   14.1083           0         1           0
#
#      Embarked_Q  Embarked_S
# 691           0           1
# 266           0           1
# 17            0           1
# 477           0           1
# 302           0           1
# ..          ...         ...
# 359           0           0
# 192           0           1
# 629           0           1
# 559           0           1
# 684           0           1
#
# [568 rows x 10 columns]

# %%
# Entrena un modelo de regresión logística utilizando la función logística personalizada
theta = np.zeros(X_train.shape[1])
alpha = 0.01
num_iters = 10000

# %%
for i in range(num_iters):
    z = np.dot(X_train, theta)
    h = custom_sigmoid(z)
    gradient = np.dot(X_train.T, (h - y_train)) / y_train.size
    theta -= alpha * gradient

# %%
# Realiza predicciones en el conjunto de prueba
y_pred = np.round(custom_sigmoid(np.dot(X_test, theta)))

# %%
# Calcula la matriz de confusión y el porcentaje de precisión
cm = confusion_matrix(y_test, y_pred)
accuracy = np.trace(cm) / np.sum(cm)

# %%
# Imprime los resultados
print('Matriz de confusión:')
print(cm)
print('Porcentaje de precisión:', accuracy)
# Out:
# Matriz de confusión:
# [[76  4]
#  [38 25]]
# Porcentaje de precisión: 0.7062937062937062

# %% [markdown]
# x_min, x_max = X.iloc[:, 0].min() - 1, X.iloc[:, 0].max() + 1
# y_min, y_max = X.iloc[:, 1].min() - 1, X.iloc[:, 1].max() + 1
# xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
# Z = np.round(custom_sigmoid(np.dot(np.c_[xx.ravel(), yy.ravel()], theta)))
# Z = Z.reshape(xx.shape)
# plt.contourf(xx, yy, Z, alpha=0.4)
# plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, s=20, edgecolor='k')
# plt.xlabel('Age')
# plt.ylabel('Fare')
# plt.title('Predicciones de supervivencia del Titanic')
# plt.show()
